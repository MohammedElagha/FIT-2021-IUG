# %% [markdown]
# # Data

# %% [markdown]
# ## Import

# %%
import pandas as pd

# %%
fatalities = pd.read_csv('https://raw.githubusercontent.com/UN-ICC/ICC-Data-Hackathon-2021/main/Refugee%20Crisis/fatalities.csv')
forciby_displaced = pd.read_csv('https://raw.githubusercontent.com/UN-ICC/ICC-Data-Hackathon-2021/main/Refugee%20Crisis/forciby_displaced.csv', encoding='latin-1')
terrain_info = pd.read_csv('https://raw.githubusercontent.com/UN-ICC/ICC-Data-Hackathon-2021/main/Refugee%20Crisis/terrain_info.csv', encoding='latin-1')
dist_cepii = pd.read_stata('https://raw.githubusercontent.com/UN-ICC/ICC-Data-Hackathon-2021/main/Refugee%20Crisis/dist_cepii.dta')
geo_cepii = pd.read_stata('https://raw.githubusercontent.com/UN-ICC/ICC-Data-Hackathon-2021/main/Refugee%20Crisis/geo_cepii.dta')

# %% [markdown]
# ## Samples

# %%
fatalities.head()
# Out:
#    Unnamed: 0  year iso_o       Country  Fatalities_acled
# 0           1  1997   AGO        Angola              5262
# 1           2  1997   BDI       Burundi              4142
# 2           3  1997   BEN         Benin                 0
# 3           4  1997   BFA  Burkina Faso                 0
# 4           5  1997   BWA      Botswana                 0

# %%
forciby_displaced.head()
# Out:
#    Unnamed: 0  Year CountryOriginCode  ...       REF  IDP ASY
# 0           1  1951               UKN  ...  180000.0  0.0   0
# 1           2  1951               UKN  ...  282000.0  0.0   0
# 2           3  1951               UKN  ...   55000.0  0.0   0
# 3           4  1951               UKN  ...  168511.0  0.0   0
# 4           5  1951               UKN  ...    2000.0  0.0   0
#
# [5 rows x 9 columns]

# %%
terrain_info.head()
# Out:
#   isocode  isonum  ...   pop_1400  european_descent
# 0     ABW     533  ...      614.0               NaN
# 1     AFG       4  ...  1870829.0               0.0
# 2     AGO      24  ...  1223208.0               2.0
# 3     AIA     660  ...        NaN               NaN
# 4     ALB       8  ...   200000.0             100.0
#
# [5 rows x 51 columns]

# %%
dist_cepii.head()
# Out:
#   iso_o iso_d  contig  ...       distcap         distw      distwces
# 0   ABW   ABW       0  ...      5.225315     25.093539     23.047228
# 1   ABW   AFG       0  ...  13257.814453  13168.223762  13166.366934
# 2   ABW   AGO       0  ...   9516.913086   9587.315563   9584.193415
# 3   ABW   AIA       0  ...    983.268250    976.897355    976.891580
# 4   ABW   ALB       0  ...   9091.742188   9091.575727   9091.465815
#
# [5 rows x 14 columns]

# %%
geo_cepii.head()
# Out:
#   iso2 iso3  cnum  ... short_colonizer1 short_colonizer2  short_colonizer3
# 0   AD  AND    20  ...
# 1   AE  ARE   784  ...
# 2   AF  AFG     4  ...              GBR
# 3   AG  ATG    28  ...
# 4   AI  AIA   660  ...
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Meta Data

# %%
fatalities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1518 entries, 0 to 1517
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1518 non-null   int64
#  1   year              1518 non-null   int64
#  2   iso_o             1518 non-null   object
#  3   Country           1518 non-null   object
#  4   Fatalities_acled  1518 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 59.4+ KB

# %%
forciby_displaced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103302 entries, 0 to 103301
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         103302 non-null  int64
#  1   Year               103302 non-null  int64
#  2   CountryOriginCode  103178 non-null  object
#  3   CountryAsylumCode  103302 non-null  object
#  4   CountryOriginName  98467 non-null   object
#  5   CountryAsylumName  103138 non-null  object
#  6   REF                103216 non-null  float64
#  7   IDP                103276 non-null  float64
#  8   ASY                103302 non-null  int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 7.1+ MB

# %%
terrain_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 51 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   isocode                 234 non-null    object
#  1   isonum                  234 non-null    int64
#  2   country                 234 non-null    object
#  3   rugged                  234 non-null    float64
#  4   rugged_popw             234 non-null    float64
#  5   rugged_slope            234 non-null    float64
#  6   rugged_lsd              234 non-null    float64
#  7   rugged_pc               234 non-null    float64
#  8   land_area               230 non-null    float64
#  9   lat                     234 non-null    float64
#  10  lon                     234 non-null    float64
#  11  soil                    225 non-null    float64
#  12  desert                  234 non-null    float64
#  13  tropical                234 non-null    float64
#  14  dist_coast              234 non-null    float64
#  15  near_coast              234 non-null    float64
#  16  gemstones               234 non-null    int64
#  17  rgdppc_2000             170 non-null    float64
#  18  rgdppc_1950_m           137 non-null    float64
#  19  rgdppc_1975_m           137 non-null    float64
#  20  rgdppc_2000_m           159 non-null    float64
#  21  rgdppc_1950_2000_m      137 non-null    float64
#  22  q_rule_law              197 non-null    float64
#  23  cont_africa             234 non-null    int64
#  24  cont_asia               234 non-null    int64
#  25  cont_europe             234 non-null    int64
#  26  cont_oceania            234 non-null    int64
#  27  cont_north_america      234 non-null    int64
#  28  cont_south_america      234 non-null    int64
#  29  legor_gbr               211 non-null    float64
#  30  legor_fra               211 non-null    float64
#  31  legor_soc               211 non-null    float64
#  32  legor_deu               211 non-null    float64
#  33  legor_sca               211 non-null    float64
#  34  colony_esp              234 non-null    int64
#  35  colony_gbr              234 non-null    int64
#  36  colony_fra              234 non-null    int64
#  37  colony_prt              234 non-null    int64
#  38  colony_oeu              234 non-null    int64
#  39  africa_region_n         234 non-null    int64
#  40  africa_region_s         234 non-null    int64
#  41  africa_region_w         234 non-null    int64
#  42  africa_region_e         234 non-null    int64
#  43  africa_region_c         234 non-null    int64
#  44  slave_exports           234 non-null    float64
#  45  dist_slavemkt_atlantic  57 non-null     float64
#  46  dist_slavemkt_indian    57 non-null     float64
#  47  dist_slavemkt_saharan   57 non-null     float64
#  48  dist_slavemkt_redsea    57 non-null     float64
#  49  pop_1400                201 non-null    float64
#  50  european_descent        165 non-null    float64
# dtypes: float64(31), int64(18), object(2)
# memory usage: 93.4+ KB

# %%
dist_cepii.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50176 entries, 0 to 50175
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   iso_o          50176 non-null  object
#  1   iso_d          50176 non-null  object
#  2   contig         50176 non-null  int8
#  3   comlang_off    50176 non-null  int8
#  4   comlang_ethno  50176 non-null  int8
#  5   colony         50176 non-null  int8
#  6   comcol         50176 non-null  int8
#  7   curcol         50176 non-null  int8
#  8   col45          50176 non-null  int8
#  9   smctry         50176 non-null  int8
#  10  dist           50176 non-null  float32
#  11  distcap        50176 non-null  float32
#  12  distw          47961 non-null  float64
#  13  distwces       47961 non-null  float64
# dtypes: float32(2), float64(2), int8(8), object(2)
# memory usage: 2.7+ MB

# %%
geo_cepii.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238 entries, 0 to 237
# Data columns (total 34 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   iso2              238 non-null    object
#  1   iso3              238 non-null    object
#  2   cnum              238 non-null    int16
#  3   country           238 non-null    object
#  4   pays              238 non-null    object
#  5   area              238 non-null    int32
#  6   dis_int           238 non-null    float32
#  7   landlocked        238 non-null    float32
#  8   continent         238 non-null    object
#  9   city_en           238 non-null    object
#  10  city_fr           238 non-null    object
#  11  lat               238 non-null    float32
#  12  lon               238 non-null    float32
#  13  cap               238 non-null    int8
#  14  maincity          238 non-null    int8
#  15  citynum           233 non-null    float32
#  16  langoff_1         238 non-null    object
#  17  langoff_2         238 non-null    object
#  18  langoff_3         238 non-null    object
#  19  lang20_1          238 non-null    object
#  20  lang20_2          238 non-null    object
#  21  lang20_3          238 non-null    object
#  22  lang20_4          238 non-null    object
#  23  lang9_1           238 non-null    object
#  24  lang9_2           238 non-null    object
#  25  lang9_3           238 non-null    object
#  26  lang9_4           238 non-null    object
#  27  colonizer1        238 non-null    object
#  28  colonizer2        238 non-null    object
#  29  colonizer3        238 non-null    object
#  30  colonizer4        238 non-null    object
#  31  short_colonizer1  238 non-null    object
#  32  short_colonizer2  238 non-null    object
#  33  short_colonizer3  238 non-null    object
# dtypes: float32(5), int16(1), int32(1), int8(2), object(25)
# memory usage: 54.9+ KB

# %% [markdown]
# ---

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Attribute Selection
# (according to business objectives)

# %% [markdown]
# ### fatalities

# %% [markdown]
# - drop Country, because iso_o is enough

# %%
fatalities = fatalities.drop('Country', axis=1)

# %%
fatalities = fatalities.drop('Unnamed: 0', axis=1)

# %% [markdown]
# ### forciby_displaced

# %% [markdown]
# - drop CountryOriginName, because CountryOriginCode is enough
# - drop CountryAsylumName, because CountryAsylumCode is enough

# %%
forciby_displaced = forciby_displaced.drop('CountryOriginName', axis=1)
forciby_displaced = forciby_displaced.drop('CountryAsylumName', axis=1)

# %%
forciby_displaced = forciby_displaced.drop('Unnamed: 0', axis=1)

# %% [markdown]
# ### terrain_info

# %% [markdown]
# - drop isonum and country, because isocode is enough
# - drop rugged_popw, rugged_slope, rugged_lsd and rugged_pc, because rugged is enough
# - drop rgdppc_2000, rgdppc_1950_m, rgdppc_1975_m and rgdppc_2000_m, because rgdppc_1950_2000_m is enough
# - drop lat and lon, because it descriptive data have no effect on the objective

# %%
terrain_info = terrain_info.drop('isonum', axis=1)
terrain_info = terrain_info.drop('country', axis=1)
terrain_info = terrain_info.drop('rugged_popw', axis=1)
terrain_info = terrain_info.drop('rugged_slope', axis=1)
terrain_info = terrain_info.drop('rugged_lsd', axis=1)
terrain_info = terrain_info.drop('rugged_pc', axis=1)
terrain_info = terrain_info.drop('rgdppc_2000', axis=1)
terrain_info = terrain_info.drop('rgdppc_1950_m', axis=1)
terrain_info = terrain_info.drop('rgdppc_1975_m', axis=1)
terrain_info = terrain_info.drop('rgdppc_2000_m', axis=1)
terrain_info = terrain_info.drop('lat', axis=1)
terrain_info = terrain_info.drop('lon', axis=1)

# %% [markdown]
# ### geo_cepii

# %% [markdown]
# - drop iso2 and cnum, becayse iso3 is enough and equal to used selected country code in previous datasets
# - drop country and pays, becayse iso3 is enough
# - drop city_en and city_fr
# - drop lat and lon, because it descriptive data have no effect on the objective
# - drop langoff_2, langoff_3, lang20_1, lang20_2, lang20_3, lang20_4, lang9_1, lang9_2, lang9_3 and lang9_4, because we need only one 'lang' representetive feature
# - drop colonizer1, colonizer2, colonizer3 and colonizer4, because has no effect and cannot be represented as one feature
# - drop short_colonizer1, short_colonizer2 and short_colonizer3, because has no effect and cannot be represented as one feature

# %%
geo_cepii = geo_cepii.drop('iso2', axis=1)
geo_cepii = geo_cepii.drop('cnum', axis=1)
geo_cepii = geo_cepii.drop('country', axis=1)
geo_cepii = geo_cepii.drop('pays', axis=1)
geo_cepii = geo_cepii.drop('city_en', axis=1)
geo_cepii = geo_cepii.drop('city_fr', axis=1)
geo_cepii = geo_cepii.drop('lat', axis=1)
geo_cepii = geo_cepii.drop('lon', axis=1)
geo_cepii = geo_cepii.drop('langoff_2', axis=1)
geo_cepii = geo_cepii.drop('langoff_3', axis=1)
geo_cepii = geo_cepii.drop('lang20_1', axis=1)
geo_cepii = geo_cepii.drop('lang20_2', axis=1)
geo_cepii = geo_cepii.drop('lang20_3', axis=1)
geo_cepii = geo_cepii.drop('lang20_4', axis=1)
geo_cepii = geo_cepii.drop('lang9_1', axis=1)
geo_cepii = geo_cepii.drop('lang9_2', axis=1)
geo_cepii = geo_cepii.drop('lang9_3', axis=1)
geo_cepii = geo_cepii.drop('lang9_4', axis=1)
geo_cepii = geo_cepii.drop('colonizer1', axis=1)
geo_cepii = geo_cepii.drop('colonizer2', axis=1)
geo_cepii = geo_cepii.drop('colonizer3', axis=1)
geo_cepii = geo_cepii.drop('colonizer4', axis=1)
geo_cepii = geo_cepii.drop('short_colonizer1', axis=1)
geo_cepii = geo_cepii.drop('short_colonizer2', axis=1)
geo_cepii = geo_cepii.drop('short_colonizer3', axis=1)

# %% [markdown]
# ## Feature Merge

# %% [markdown]
# ### terrain_info

# %% [markdown]
# merge dummy variables ['cont_africa','cont_asia','cont_europe','cont_oceania','cont_north_america','cont_south_america'] to categorial attribute 'cont'

# %%
terrain_info['cont'] = terrain_info.loc[:, ['cont_africa','cont_asia','cont_europe','cont_oceania','cont_north_america','cont_south_america']].idxmax(1)

# %%
terrain_info = terrain_info.drop(['cont_africa','cont_asia','cont_europe','cont_oceania','cont_north_america','cont_south_america'], axis=1)

# %% [markdown]
# merge dummy variables ['legor_gbr','legor_fra','legor_soc','legor_deu','legor_sca'] to categorial attribute 'legor'

# %%
terrain_info['legor'] = terrain_info.loc[:, ['legor_gbr','legor_fra','legor_soc','legor_deu','legor_sca']].idxmax(1)

# %%
terrain_info = terrain_info.drop(['legor_gbr','legor_fra','legor_soc','legor_deu','legor_sca'], axis=1)

# %% [markdown]
# merge dummy variables ['colony_esp','colony_gbr','colony_fra','colony_prt','colony_oeu'] to categorial attribute 'colony'

# %%
terrain_info['colony'] = terrain_info.loc[:, ['colony_esp','colony_gbr','colony_fra','colony_prt','colony_oeu']].idxmax(1)

# %%
terrain_info = terrain_info.drop(['colony_esp','colony_gbr','colony_fra','colony_prt','colony_oeu'], axis=1)

# %% [markdown]
# merge dummy variables ['africa_region_n','africa_region_s','africa_region_w','africa_region_e','africa_region_c'] to categorial attribute 'colony'

# %%
terrain_info['africa_region'] = terrain_info.loc[:, ['africa_region_n','africa_region_s','africa_region_w','africa_region_e','africa_region_c']].idxmax(1)

# %%
terrain_info = terrain_info.drop(['africa_region_n','africa_region_s','africa_region_w','africa_region_e','africa_region_c'], axis=1)

# %% [markdown]
# ## Missing Values Handling

# %% [markdown]
# ### fatalities

# %% [markdown]
# - drop na rows, because it little

# %%
fatalities = fatalities.dropna()

# %%
fatalities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1518 entries, 0 to 1517
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              1518 non-null   int64
#  1   iso_o             1518 non-null   object
#  2   Fatalities_acled  1518 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 47.4+ KB

# %% [markdown]
# ### forciby_displaced

# %% [markdown]
# - drop na rows, because it little

# %%
forciby_displaced = forciby_displaced.dropna()

# %%
forciby_displaced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103066 entries, 0 to 103301
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Year               103066 non-null  int64
#  1   CountryOriginCode  103066 non-null  object
#  2   CountryAsylumCode  103066 non-null  object
#  3   REF                103066 non-null  float64
#  4   IDP                103066 non-null  float64
#  5   ASY                103066 non-null  int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 5.5+ MB

# %% [markdown]
# ### terrain_info

# %% [markdown]
# - drop columns with a lot of missings
# - then drop na rows

# %%
terrain_info = terrain_info.drop(['rgdppc_1950_2000_m', 'q_rule_law', 
                                  'dist_slavemkt_atlantic', 'dist_slavemkt_indian', 'dist_slavemkt_saharan', 'dist_slavemkt_redsea', 
                                  'pop_1400', 'european_descent'], axis=1)

# %%
terrain_info = terrain_info.dropna()

# %%
terrain_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 208 entries, 0 to 233
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   isocode        208 non-null    object
#  1   rugged         208 non-null    float64
#  2   land_area      208 non-null    float64
#  3   soil           208 non-null    float64
#  4   desert         208 non-null    float64
#  5   tropical       208 non-null    float64
#  6   dist_coast     208 non-null    float64
#  7   near_coast     208 non-null    float64
#  8   gemstones      208 non-null    int64
#  9   slave_exports  208 non-null    float64
#  10  cont           208 non-null    object
#  11  legor          208 non-null    object
#  12  colony         208 non-null    object
#  13  africa_region  208 non-null    object
# dtypes: float64(8), int64(1), object(5)
# memory usage: 24.4+ KB

# %% [markdown]
# ### dist_cepii

# %%
dist_cepii = dist_cepii.dropna()

# %%
dist_cepii.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47961 entries, 0 to 50175
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   iso_o          47961 non-null  object
#  1   iso_d          47961 non-null  object
#  2   contig         47961 non-null  int8
#  3   comlang_off    47961 non-null  int8
#  4   comlang_ethno  47961 non-null  int8
#  5   colony         47961 non-null  int8
#  6   comcol         47961 non-null  int8
#  7   curcol         47961 non-null  int8
#  8   col45          47961 non-null  int8
#  9   smctry         47961 non-null  int8
#  10  dist           47961 non-null  float32
#  11  distcap        47961 non-null  float32
#  12  distw          47961 non-null  float64
#  13  distwces       47961 non-null  float64
# dtypes: float32(2), float64(2), int8(8), object(2)
# memory usage: 2.6+ MB

# %% [markdown]
# ### geo_cepii

# %%
geo_cepii = geo_cepii.dropna()

# %%
geo_cepii.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233 entries, 0 to 237
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   iso3        233 non-null    object
#  1   area        233 non-null    int32
#  2   dis_int     233 non-null    float32
#  3   landlocked  233 non-null    float32
#  4   continent   233 non-null    object
#  5   cap         233 non-null    int8
#  6   maincity    233 non-null    int8
#  7   citynum     233 non-null    float32
#  8   langoff_1   233 non-null    object
# dtypes: float32(3), int32(1), int8(2), object(3)
# memory usage: 11.4+ KB

# %% [markdown]
# ## Datatype Conversion (categorial to numeric)

# %% [markdown]
# ### terrain_info

# %%
terrain_info_cols = terrain_info.columns.delete(0)

# %%
for col_name in terrain_info_cols:
    if(terrain_info[col_name].dtype == 'object'):
        terrain_info[col_name]= terrain_info[col_name].astype('category')
        terrain_info[col_name] = terrain_info[col_name].cat.codes

# %% [markdown]
# ### dist_cepii

# %%
dist_cepii_cols = dist_cepii.columns.delete(0).delete(0)

# %%
for col_name in dist_cepii_cols:
    if(dist_cepii[col_name].dtype == 'object'):
        dist_cepii[col_name]= dist_cepii[col_name].astype('category')
        dist_cepii[col_name] = dist_cepii[col_name].cat.codes

# %% [markdown]
# ### geo_cepii

# %%
geo_cepii_cols = geo_cepii.columns.delete(0).delete(0)

# %%
for col_name in geo_cepii_cols:
    if(geo_cepii[col_name].dtype == 'object'):
        geo_cepii[col_name]= geo_cepii[col_name].astype('category')
        geo_cepii[col_name] = geo_cepii[col_name].cat.codes

# %% [markdown]
# ## Clustering

# %%
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# ### terrain_info

# %%
clustered_terrain_info = terrain_info.drop('isocode', axis=1)

# %%
dendrogram = sch.dendrogram(sch.linkage(clustered_terrain_info, method  = "ward"))
plt.show()

# %%
clustered_terrain_info_hc = AgglomerativeClustering(n_clusters = 5, affinity = 'euclidean', linkage ='ward')

# %%
y_clustered_terrain_info_hc=clustered_terrain_info_hc.fit_predict(clustered_terrain_info)

# %% [markdown]
# ### geo_cepii

# %%
clustered_geo_cepii = geo_cepii.drop('iso3', axis=1)

# %%
dendrogram = sch.dendrogram(sch.linkage(clustered_geo_cepii, method  = "ward"))
plt.show()

# %%
clustered_geo_cepii_hc = AgglomerativeClustering(n_clusters = 4, affinity = 'euclidean', linkage ='ward')

# %%
y_clustered_geo_cepii_hc=clustered_geo_cepii_hc.fit_predict(clustered_geo_cepii)

# %% [markdown]
# ## Feature Generation

# %% [markdown]
# Instead of clustering, for huge datasets

# %% [markdown]
# ### dist_cepii

# %%
dist_cepii['dist_avg'] = dist_cepii[['contig','comlang_off','comlang_ethno','colony','comcol','curcol','col45','smctry','dist',
                                                   'distcap','distw','distwces']].mean(axis=1)
dist_cepii['dist_avg'].head()
# Out:
# 0       4.882616
# 1    4404.184967
# 2    3183.777929
# 3     326.777120
# 4    3030.543826
# Name: dist_avg, dtype: float64

# %%
dist_cepii = dist_cepii.drop(['contig','comlang_off','comlang_ethno','colony','comcol','curcol','col45','smctry','dist',
                                                   'distcap','distw','distwces'], axis=1)

# %%
dist_cepii = dist_cepii.dropna()

# %%
dist_cepii.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47961 entries, 0 to 50175
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   iso_o     47961 non-null  object
#  1   iso_d     47961 non-null  object
#  2   dist_avg  47961 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 1.5+ MB

# %% [markdown]
# ## Set ISO-Code to Data

# %% [markdown]
# ### terrain_info

# %%
ready_terrain_info = pd.DataFrame(data={'isocode': terrain_info['isocode'], 'hc': y_clustered_terrain_info_hc})

# %%
ready_terrain_info.head()
# Out:
#   isocode  hc
# 0     ABW   1
# 1     AFG   1
# 2     AGO   2
# 4     ALB   1
# 5     AND   1

# %%
ready_terrain_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 208 entries, 0 to 233
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   isocode  208 non-null    object
#  1   hc       208 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 4.9+ KB

# %% [markdown]
# ### geo_cepii

# %%
ready_geo_cepii = pd.DataFrame(data={'iso3': geo_cepii['iso3'], 'hc': y_clustered_geo_cepii_hc})

# %%
ready_geo_cepii.head()
# Out:
#   iso3  hc
# 0  AND   0
# 1  ARE   0
# 2  AFG   0
# 3  ATG   0
# 4  AIA   0

# %%
ready_geo_cepii.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233 entries, 0 to 237
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   iso3    233 non-null    object
#  1   hc      233 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.5+ KB

# %% [markdown]
# ## After Preprocessing

# %%
final_fatalities = fatalities
final_forciby_displaced = forciby_displaced
final_terrain_info = ready_terrain_info
final_dist_cepii = dist_cepii
final_geo_cepii = ready_geo_cepii

# %%
final_fatalities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1518 entries, 0 to 1517
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              1518 non-null   int64
#  1   iso_o             1518 non-null   object
#  2   Fatalities_acled  1518 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 47.4+ KB

# %%
final_forciby_displaced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103066 entries, 0 to 103301
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Year               103066 non-null  int64
#  1   CountryOriginCode  103066 non-null  object
#  2   CountryAsylumCode  103066 non-null  object
#  3   REF                103066 non-null  float64
#  4   IDP                103066 non-null  float64
#  5   ASY                103066 non-null  int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 5.5+ MB

# %%
final_terrain_info = final_terrain_info.rename(columns={'hc': 'terrain_hc'})
final_terrain_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 208 entries, 0 to 233
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   isocode     208 non-null    object
#  1   terrain_hc  208 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 4.9+ KB

# %%
final_dist_cepii.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47961 entries, 0 to 50175
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   iso_o     47961 non-null  object
#  1   iso_d     47961 non-null  object
#  2   dist_avg  47961 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 1.5+ MB

# %%
final_geo_cepii = final_geo_cepii.rename(columns={'hc': 'geo_hc'})
final_geo_cepii.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233 entries, 0 to 237
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   iso3    233 non-null    object
#  1   geo_hc  233 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.5+ KB

# %% [markdown]
# ## Combination

# %% [markdown]
# ### First Combination

# %%
data = pd.merge(final_fatalities, final_forciby_displaced, how='right', left_on=['iso_o','year'], right_on=['CountryOriginCode','Year'])

# %%
data.rename(columns={'Fatalities_acled': 'OriginFatalitiesAcled'}, inplace=True)

# %%
data = pd.merge(final_fatalities, data, how='right', left_on=['iso_o','year'], right_on=['CountryAsylumCode','Year'])

# %%
data.rename(columns={'Fatalities_acled': 'DistFatalitiesAcled', 'CountryAsylumCode': 'CountryDistCode'}, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103066 entries, 0 to 103065
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   year_x                 19653 non-null   float64
#  1   iso_o_x                19653 non-null   object
#  2   DistFatalitiesAcled    19653 non-null   float64
#  3   year_y                 47506 non-null   float64
#  4   iso_o_y                47506 non-null   object
#  5   OriginFatalitiesAcled  47506 non-null   float64
#  6   Year                   103066 non-null  int64
#  7   CountryOriginCode      103066 non-null  object
#  8   CountryDistCode        103066 non-null  object
#  9   REF                    103066 non-null  float64
#  10  IDP                    103066 non-null  float64
#  11  ASY                    103066 non-null  int64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 10.2+ MB

# %%
data.drop(['year_x', 'iso_o_x', 'year_y', 'iso_o_y'], axis=1, inplace=True)

# %%
data['OriginFatalitiesAcled'].fillna(0, inplace=True)
data['DistFatalitiesAcled'].fillna(0, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103066 entries, 0 to 103065
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   DistFatalitiesAcled    103066 non-null  float64
#  1   OriginFatalitiesAcled  103066 non-null  float64
#  2   Year                   103066 non-null  int64
#  3   CountryOriginCode      103066 non-null  object
#  4   CountryDistCode        103066 non-null  object
#  5   REF                    103066 non-null  float64
#  6   IDP                    103066 non-null  float64
#  7   ASY                    103066 non-null  int64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 7.1+ MB

# %% [markdown]
# ### Second Combination

# %%
data = pd.merge(data, final_terrain_info, how='left', left_on=['CountryOriginCode'], right_on=['isocode'])

# %%
data.rename(columns={'terrain_hc': 'origin_terrain_hc'}, inplace=True)

# %%
data = pd.merge(data, final_terrain_info, how='left', left_on=['CountryDistCode'], right_on=['isocode'])

# %%
data.rename(columns={'terrain_hc': 'dist_terrain_hc'}, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103066 entries, 0 to 103065
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   DistFatalitiesAcled    103066 non-null  float64
#  1   OriginFatalitiesAcled  103066 non-null  float64
#  2   Year                   103066 non-null  int64
#  3   CountryOriginCode      103066 non-null  object
#  4   CountryDistCode        103066 non-null  object
#  5   REF                    103066 non-null  float64
#  6   IDP                    103066 non-null  float64
#  7   ASY                    103066 non-null  int64
#  8   isocode_x              95059 non-null   object
#  9   origin_terrain_hc      95059 non-null   float64
#  10  isocode_y              102069 non-null  object
#  11  dist_terrain_hc        102069 non-null  float64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 10.2+ MB

# %%
data.drop(['isocode_x', 'isocode_y'], axis=1, inplace=True)

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94258 entries, 159 to 103065
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DistFatalitiesAcled    94258 non-null  float64
#  1   OriginFatalitiesAcled  94258 non-null  float64
#  2   Year                   94258 non-null  int64
#  3   CountryOriginCode      94258 non-null  object
#  4   CountryDistCode        94258 non-null  object
#  5   REF                    94258 non-null  float64
#  6   IDP                    94258 non-null  float64
#  7   ASY                    94258 non-null  int64
#  8   origin_terrain_hc      94258 non-null  float64
#  9   dist_terrain_hc        94258 non-null  float64
# dtypes: float64(6), int64(2), object(2)
# memory usage: 7.9+ MB

# %% [markdown]
# ### Third Combination

# %%
data = pd.merge(data, final_geo_cepii, how='left', left_on=['CountryOriginCode'], right_on=['iso3'])

# %%
data.rename(columns={'geo_hc': 'origin_geo_hc'}, inplace=True)

# %%
data = pd.merge(data, final_geo_cepii, how='left', left_on=['CountryDistCode'], right_on=['iso3'])

# %%
data.rename(columns={'geo_hc': 'dist_geo_hc'}, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 122224 entries, 0 to 122223
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   DistFatalitiesAcled    122224 non-null  float64
#  1   OriginFatalitiesAcled  122224 non-null  float64
#  2   Year                   122224 non-null  int64
#  3   CountryOriginCode      122224 non-null  object
#  4   CountryDistCode        122224 non-null  object
#  5   REF                    122224 non-null  float64
#  6   IDP                    122224 non-null  float64
#  7   ASY                    122224 non-null  int64
#  8   origin_terrain_hc      122224 non-null  float64
#  9   dist_terrain_hc        122224 non-null  float64
#  10  iso3_x                 118788 non-null  object
#  11  origin_geo_hc          118788 non-null  float64
#  12  iso3_y                 120853 non-null  object
#  13  dist_geo_hc            120853 non-null  float64
# dtypes: float64(8), int64(2), object(4)
# memory usage: 14.0+ MB

# %%
data.drop(['iso3_x', 'iso3_y'], axis=1, inplace=True)

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117459 entries, 3 to 122223
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   DistFatalitiesAcled    117459 non-null  float64
#  1   OriginFatalitiesAcled  117459 non-null  float64
#  2   Year                   117459 non-null  int64
#  3   CountryOriginCode      117459 non-null  object
#  4   CountryDistCode        117459 non-null  object
#  5   REF                    117459 non-null  float64
#  6   IDP                    117459 non-null  float64
#  7   ASY                    117459 non-null  int64
#  8   origin_terrain_hc      117459 non-null  float64
#  9   dist_terrain_hc        117459 non-null  float64
#  10  origin_geo_hc          117459 non-null  float64
#  11  dist_geo_hc            117459 non-null  float64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 11.6+ MB

# %% [markdown]
# ### Forth Combination

# %%
data = pd.merge(data, final_dist_cepii, how='left', left_on=['CountryOriginCode', 'CountryDistCode'], right_on=['iso_o', 'iso_d'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117459 entries, 0 to 117458
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   DistFatalitiesAcled    117459 non-null  float64
#  1   OriginFatalitiesAcled  117459 non-null  float64
#  2   Year                   117459 non-null  int64
#  3   CountryOriginCode      117459 non-null  object
#  4   CountryDistCode        117459 non-null  object
#  5   REF                    117459 non-null  float64
#  6   IDP                    117459 non-null  float64
#  7   ASY                    117459 non-null  int64
#  8   origin_terrain_hc      117459 non-null  float64
#  9   dist_terrain_hc        117459 non-null  float64
#  10  origin_geo_hc          117459 non-null  float64
#  11  dist_geo_hc            117459 non-null  float64
#  12  iso_o                  117459 non-null  object
#  13  iso_d                  117459 non-null  object
#  14  dist_avg               117459 non-null  float64
# dtypes: float64(9), int64(2), object(4)
# memory usage: 14.3+ MB

# %%
data.drop(['iso_o', 'iso_d'], axis=1, inplace=True)

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117459 entries, 0 to 117458
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   DistFatalitiesAcled    117459 non-null  float64
#  1   OriginFatalitiesAcled  117459 non-null  float64
#  2   Year                   117459 non-null  int64
#  3   CountryOriginCode      117459 non-null  object
#  4   CountryDistCode        117459 non-null  object
#  5   REF                    117459 non-null  float64
#  6   IDP                    117459 non-null  float64
#  7   ASY                    117459 non-null  int64
#  8   origin_terrain_hc      117459 non-null  float64
#  9   dist_terrain_hc        117459 non-null  float64
#  10  origin_geo_hc          117459 non-null  float64
#  11  dist_geo_hc            117459 non-null  float64
#  12  dist_avg               117459 non-null  float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 12.5+ MB

# %% [markdown]
# ### Convert Year ot DateTime

# %%
data['date_time'] = '31/12/' + data['Year'].map(str) + ' 23.59.59'
data['date_time'] = pd.to_datetime(data.date_time , format = '%d/%m/%Y %H.%M.%S')
data = data.drop(['Year'], axis=1)
# data.index = data.date_time
# data = data.drop(['date_time'], axis=1)

# %%
data.tail()
# Out:
#         DistFatalitiesAcled  ...           date_time
# 117454                245.0  ... 2019-12-31 23:59:59
# 117455                  5.0  ... 2019-12-31 23:59:59
# 117456                  0.0  ... 2019-12-31 23:59:59
# 117457                  0.0  ... 2019-12-31 23:59:59
# 117458                  0.0  ... 2019-12-31 23:59:59
#
# [5 rows x 13 columns]

# %% [markdown]
# ### Generate Fake Variance

# %%
import random

# %%
data['origin_terrain_hc'] = data['origin_terrain_hc'].apply(lambda x: x + random.uniform(0.0146541654, 0.35464654516))
data['dist_terrain_hc'] = data['dist_terrain_hc'].apply(lambda x: x + random.uniform(0.0146541654, 0.35464654516))
data['origin_geo_hc'] = data['origin_geo_hc'].apply(lambda x: x + random.uniform(0.0146541654, 0.35464654516))
data['dist_geo_hc'] = data['dist_geo_hc'].apply(lambda x: x + random.uniform(0.0146541654, 0.35464654516))
data['dist_avg'] = data['dist_avg'].apply(lambda x: x + random.uniform(0.0146541654, 0.35464654516))

# %%
data.tail()
# Out:
#         DistFatalitiesAcled  ...           date_time
# 117454                245.0  ... 2019-12-31 23:59:59
# 117455                  5.0  ... 2019-12-31 23:59:59
# 117456                  0.0  ... 2019-12-31 23:59:59
# 117457                  0.0  ... 2019-12-31 23:59:59
# 117458                  0.0  ... 2019-12-31 23:59:59
#
# [5 rows x 13 columns]

# %% [markdown]
# # Visualization

# %%
SYR_to_LBN = data[(data.CountryOriginCode == "SYR") & (data.CountryDistCode == "LBN")]

# %%
SYR_to_LBN.tail()
# Out:
#         DistFatalitiesAcled  ...           date_time
# 90691                   0.0  ... 2015-12-31 23:59:59
# 96369                 187.0  ... 2016-12-31 23:59:59
# 102301                366.0  ... 2017-12-31 23:59:59
# 108224                 17.0  ... 2018-12-31 23:59:59
# 114437                 21.0  ... 2019-12-31 23:59:59
#
# [5 rows x 13 columns]

# %%
from matplotlib import pyplot

# %%
values = data.values
# specify columns to plot
groups = [4,5,6]
i = 1
# plot each column
pyplot.figure()
for group in groups:
	pyplot.subplot(len(groups), 1, i)
	pyplot.plot(values[:, group])
	pyplot.title(data.columns[group], y=0.5, loc='right')
	i += 1
pyplot.show()

# %% [markdown]
# # Modeling

# %%
SYR_to_LBN_data = SYR_to_LBN.drop(['CountryOriginCode', 'CountryDistCode'], axis=1)

# %%
SYR_to_LBN_data.tail()
# Out:
#         DistFatalitiesAcled  ...           date_time
# 90691                   0.0  ... 2015-12-31 23:59:59
# 96369                 187.0  ... 2016-12-31 23:59:59
# 102301                366.0  ... 2017-12-31 23:59:59
# 108224                 17.0  ... 2018-12-31 23:59:59
# 114437                 21.0  ... 2019-12-31 23:59:59
#
# [5 rows x 11 columns]

# %%
SYR_to_LBN_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 129 to 114437
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DistFatalitiesAcled    25 non-null     float64
#  1   OriginFatalitiesAcled  25 non-null     float64
#  2   REF                    25 non-null     float64
#  3   IDP                    25 non-null     float64
#  4   ASY                    25 non-null     int64
#  5   origin_terrain_hc      25 non-null     float64
#  6   dist_terrain_hc        25 non-null     float64
#  7   origin_geo_hc          25 non-null     float64
#  8   dist_geo_hc            25 non-null     float64
#  9   dist_avg               25 non-null     float64
#  10  date_time              25 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(9), int64(1)
# memory usage: 2.3 KB

# %%
SYR_to_LBN_data
# Out:
#         DistFatalitiesAcled  ...           date_time
# 129                     0.0  ... 1968-12-31 23:59:59
# 171                     0.0  ... 1969-12-31 23:59:59
# 854                     0.0  ... 1979-12-31 23:59:59
# 998                     0.0  ... 1980-12-31 23:59:59
# 1135                    0.0  ... 1981-12-31 23:59:59
# 1291                    0.0  ... 1982-12-31 23:59:59
# 1478                    0.0  ... 1983-12-31 23:59:59
# 1669                    0.0  ... 1984-12-31 23:59:59
# 1878                    0.0  ... 1985-12-31 23:59:59
# 2076                    0.0  ... 1986-12-31 23:59:59
# 2564                    0.0  ... 1988-12-31 23:59:59
# 45750                   0.0  ... 2006-12-31 23:59:59
# 50272                   0.0  ... 2007-12-31 23:59:59
# 54965                   0.0  ... 2008-12-31 23:59:59
# 59662                   0.0  ... 2009-12-31 23:59:59
# 64425                   0.0  ... 2010-12-31 23:59:59
# 69417                   0.0  ... 2011-12-31 23:59:59
# 74410                   0.0  ... 2012-12-31 23:59:59
# 79570                   0.0  ... 2013-12-31 23:59:59
# 85035                   0.0  ... 2014-12-31 23:59:59
# 90691                   0.0  ... 2015-12-31 23:59:59
# 96369                 187.0  ... 2016-12-31 23:59:59
# 102301                366.0  ... 2017-12-31 23:59:59
# 108224                 17.0  ... 2018-12-31 23:59:59
# 114437                 21.0  ... 2019-12-31 23:59:59
#
# [25 rows x 11 columns]

# %% [markdown]
# # Modeling

# %%
df = SYR_to_LBN_data

# %%
SYR_to_LBN_data.groupby('date_time').count()
# Out:
#                      DistFatalitiesAcled  ...  dist_avg
# date_time                                 ...
# 1968-12-31 23:59:59                    1  ...         1
# 1969-12-31 23:59:59                    1  ...         1
# 1979-12-31 23:59:59                    1  ...         1
# 1980-12-31 23:59:59                    1  ...         1
# 1981-12-31 23:59:59                    1  ...         1
# 1982-12-31 23:59:59                    1  ...         1
# 1983-12-31 23:59:59                    1  ...         1
# 1984-12-31 23:59:59                    1  ...         1
# 1985-12-31 23:59:59                    1  ...         1
# 1986-12-31 23:59:59                    1  ...         1
# 1988-12-31 23:59:59                    1  ...         1
# 2006-12-31 23:59:59                    1  ...         1
# 2007-12-31 23:59:59                    1  ...         1
# 2008-12-31 23:59:59                    1  ...         1
# 2009-12-31 23:59:59                    1  ...         1
# 2010-12-31 23:59:59                    1  ...         1
# 2011-12-31 23:59:59                    1  ...         1
# 2012-12-31 23:59:59                    1  ...         1
# 2013-12-31 23:59:59                    1  ...         1
# 2014-12-31 23:59:59                    1  ...         1
# 2015-12-31 23:59:59                    1  ...         1
# 2016-12-31 23:59:59                    1  ...         1
# 2017-12-31 23:59:59                    1  ...         1
# 2018-12-31 23:59:59                    1  ...         1
# 2019-12-31 23:59:59                    1  ...         1
#
# [25 rows x 10 columns]

# %%
pd.unique(SYR_to_LBN_data['date_time'])
# Out:
# array(['1968-12-31T23:59:59.000000000', '1969-12-31T23:59:59.000000000',
#        '1979-12-31T23:59:59.000000000', '1980-12-31T23:59:59.000000000',
#        '1981-12-31T23:59:59.000000000', '1982-12-31T23:59:59.000000000',
#        '1983-12-31T23:59:59.000000000', '1984-12-31T23:59:59.000000000',
#        '1985-12-31T23:59:59.000000000', '1986-12-31T23:59:59.000000000',
#        '1988-12-31T23:59:59.000000000', '2006-12-31T23:59:59.000000000',
#        '2007-12-31T23:59:59.000000000', '2008-12-31T23:59:59.000000000',
#        '2009-12-31T23:59:59.000000000', '2010-12-31T23:59:59.000000000',
#        '2011-12-31T23:59:59.000000000', '2012-12-31T23:59:59.000000000',
#        '2013-12-31T23:59:59.000000000', '2014-12-31T23:59:59.000000000',
#        '2015-12-31T23:59:59.000000000', '2016-12-31T23:59:59.000000000',
#        '2017-12-31T23:59:59.000000000', '2018-12-31T23:59:59.000000000',
#        '2019-12-31T23:59:59.000000000'], dtype='datetime64[ns]')

# %%
df = df.set_index('date_time')

# %%
df.count()
# Out:
# DistFatalitiesAcled      25
# OriginFatalitiesAcled    25
# REF                      25
# IDP                      25
# ASY                      25
# origin_terrain_hc        25
# dist_terrain_hc          25
# origin_geo_hc            25
# dist_geo_hc              25
# dist_avg                 25
# dtype: int64

# %%
from pandas import read_csv
from matplotlib import pyplot

values = df.values
# specify columns to plot
groups = [0, 1, 2]
i = 1
# plot each column
pyplot.figure()
for group in groups:
	pyplot.subplot(len(groups), 1, i)
	pyplot.plot(values[:, group])
	pyplot.title(df.columns[group], y=0.5, loc='right')
	i += 1
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot

values = df.values
# specify columns to plot
groups = [3, 5, 6]
i = 1
# plot each column
pyplot.figure()
for group in groups:
	pyplot.subplot(len(groups), 1, i)
	pyplot.plot(values[:, group])
	pyplot.title(df.columns[group], y=0.5, loc='right')
	i += 1
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot

values = df.values
# specify columns to plot
groups = [ 7,8,9]
i = 1
# plot each column
pyplot.figure()
for group in groups:
	pyplot.subplot(len(groups), 1, i)
	pyplot.plot(values[:, group])
	pyplot.title(df.columns[group], y=0.5, loc='right')
	i += 1
pyplot.show()

# %%
values[0]
# Out:
# array([0.00000000e+00, 0.00000000e+00, 1.20000000e+03, 0.00000000e+00,
#        0.00000000e+00, 1.10690067e+00, 1.01575602e+00, 6.05039941e-02,
#        9.28483044e-02, 4.66604279e+01])

# %%
# prepare data for lstm
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# load dataset
values = df.values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 5)
# drop columns we don't want to predict
#reframed.drop(reframed.columns[[9,10,11,12,13,14,15]], axis=1, inplace=True)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  ...  var8(t+4)  var9(t+4)  var10(t+4)
# 1        0.0        0.0   0.001041  ...   0.000000   0.541989    0.551361
# 2        0.0        0.0   0.001041  ...   0.611167   0.093099    0.570145
# 3        0.0        0.0   0.000431  ...   1.000000   0.350423    0.696899
# 4        0.0        0.0   0.000431  ...   0.668115   0.719469    0.648285
# 5        0.0        0.0   0.000431  ...   0.340555   0.215922    0.847565
#
# [5 rows x 60 columns]

# %%
for i in range(1, 0, -1) : print(i)
# Out:
# 1

# %%
reframed
# Out:
#     var1(t-1)  var2(t-1)  var3(t-1)  ...  var8(t+4)  var9(t+4)  var10(t+4)
# 1         0.0        0.0   0.001041  ...   0.000000   0.541989    0.551361
# 2         0.0        0.0   0.001041  ...   0.611167   0.093099    0.570145
# 3         0.0        0.0   0.000431  ...   1.000000   0.350423    0.696899
# 4         0.0        0.0   0.000431  ...   0.668115   0.719469    0.648285
# 5         0.0        0.0   0.000431  ...   0.340555   0.215922    0.847565
# 6         0.0        0.0   0.000431  ...   0.306902   0.393198    0.942612
# 7         0.0        0.0   0.000448  ...   0.318475   0.000000    0.149170
# 8         0.0        0.0   0.000448  ...   0.909587   0.421838    0.324005
# 9         0.0        0.0   0.000509  ...   0.483191   0.669909    0.123901
# 10        0.0        0.0   0.000448  ...   0.849020   0.563088    0.493881
# 11        0.0        0.0   0.000448  ...   0.708832   0.358651    1.000000
# 12        0.0        0.0   0.000000  ...   0.461764   0.667253    0.475021
# 13        0.0        0.0   0.000037  ...   0.978427   0.415051    0.577347
# 14        0.0        0.0   0.000068  ...   0.022447   0.545520    0.068176
# 15        0.0        0.0   0.000073  ...   0.055044   0.306935    0.044617
# 16        0.0        0.0   0.000051  ...   0.938217   0.411059    0.017197
# 17        0.0        0.0   0.000103  ...   0.665253   0.496039    0.736404
# 18        0.0        0.0   0.110618  ...   0.117218   0.682759    0.000000
# 19        0.0        0.0   0.741862  ...   0.359247   0.389684    0.151962
# 20        0.0        0.0   1.000000  ...   0.015548   0.614426    0.779510
#
# [20 rows x 60 columns]

# %%
len(values)
# Out:
# 25

# %%
# split into train and test sets
values = reframed.values
n_train_hours = 15
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (15, 1, 59) (15,) (5, 1, 59) (5,)

# %%
train[0]
# Out:
# array([0.0000000e+00, 0.0000000e+00, 1.0405338e-03, 0.0000000e+00,
#        0.0000000e+00, 2.5995374e-01, 0.0000000e+00, 1.3639726e-01,
#        4.3180406e-02, 1.0852051e-01, 0.0000000e+00, 0.0000000e+00,
#        1.0405338e-03, 0.0000000e+00, 0.0000000e+00, 5.4533720e-01,
#        8.6138129e-01, 8.9414144e-01, 1.0000000e+00, 4.4241333e-01,
#        0.0000000e+00, 0.0000000e+00, 4.3050558e-04, 0.0000000e+00,
#        0.0000000e+00, 6.9386339e-01, 4.0522623e-01, 1.5706651e-02,
#        6.3707507e-01, 6.1853027e-01, 0.0000000e+00, 0.0000000e+00,
#        4.3050558e-04, 0.0000000e+00, 0.0000000e+00, 4.9681902e-02,
#        8.7161636e-01, 9.1563511e-01, 8.1121755e-01, 3.5174561e-01,
#        0.0000000e+00, 0.0000000e+00, 4.3050558e-04, 0.0000000e+00,
#        0.0000000e+00, 7.0028853e-01, 7.0198488e-01, 3.8755646e-01,
#        2.2219735e-01, 9.3841553e-03, 0.0000000e+00, 0.0000000e+00,
#        4.3050558e-04, 0.0000000e+00, 0.0000000e+00, 5.1638365e-01,
#        3.6556220e-01, 0.0000000e+00, 5.4198861e-01, 5.5136108e-01],
#       dtype=float32)

# %%
test[0]
# Out:
# array([0.00000000e+00, 0.00000000e+00, 5.05451899e-05, 0.00000000e+00,
#        3.37320566e-01, 2.69893169e-01, 8.70373011e-01, 7.08832264e-01,
#        3.58651400e-01, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.02833314e-04, 0.00000000e+00, 8.80382717e-01, 1.00000000e+00,
#        4.49962854e-01, 4.61763769e-01, 6.67253137e-01, 4.75021362e-01,
#        0.00000000e+00, 0.00000000e+00, 1.10618144e-01, 0.00000000e+00,
#        5.78947365e-01, 6.57140493e-01, 6.17443562e-01, 9.78427172e-01,
#        4.15050805e-01, 5.77346802e-01, 0.00000000e+00, 0.00000000e+00,
#        7.41862178e-01, 0.00000000e+00, 7.94258356e-01, 9.53787804e-01,
#        1.23814344e-01, 2.24474370e-02, 5.45519590e-01, 6.81762695e-02,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        9.99999940e-01, 4.55558300e-01, 3.77049208e-01, 5.50443381e-02,
#        3.06935191e-01, 4.46166992e-02, 0.00000000e+00, 0.00000000e+00,
#        9.26095903e-01, 0.00000000e+00, 3.82775106e-02, 3.43623161e-01,
#        1.00000000e+00, 9.38217282e-01, 4.11058843e-01, 1.71966553e-02],
#       dtype=float32)

# %%
from tensorflow.keras import layers
import tensorflow as tf
from tensorflow.keras import Sequential , layers
import matplotlib.pyplot as plt

# design network

lstm_model = tf.keras.models.Sequential([
    # Shape [batch, time, features] => [batch, time, lstm_units]
    tf.keras.layers.LSTM(32, return_sequences=True , input_shape=(train_X.shape[1], train_X.shape[2])),
    # Shape => [batch, time, features]
    tf.keras.layers.Dense(units=1)
])


lstm_model.compile(loss='mae', optimizer='adam',
              metrics=['accuracy'])
# fit network
history = lstm_model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y),validation_steps=30 , verbose=2, shuffle=False)

# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/50
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 30 batches). You may need to use the repeat() function when building your dataset.
# 1/1 - 3s - loss: 0.5409 - accuracy: 0.0000e+00 - val_loss: 0.3507 - val_accuracy: 0.2000
# Epoch 2/50
# 1/1 - 0s - loss: 0.5149 - accuracy: 0.0000e+00
# Epoch 3/50
# 1/1 - 0s - loss: 0.4889 - accuracy: 0.0000e+00
# Epoch 4/50
# 1/1 - 0s - loss: 0.4637 - accuracy: 0.0000e+00
# Epoch 5/50
# 1/1 - 0s - loss: 0.4426 - accuracy: 0.0000e+00
# Epoch 6/50
# 1/1 - 0s - loss: 0.4269 - accuracy: 0.0000e+00
# Epoch 7/50
# 1/1 - 0s - loss: 0.4126 - accuracy: 0.0000e+00
# Epoch 8/50
# 1/1 - 0s - loss: 0.3984 - accuracy: 0.0000e+00
# Epoch 9/50
# 1/1 - 0s - loss: 0.3876 - accuracy: 0.0000e+00
# Epoch 10/50
# 1/1 - 0s - loss: 0.3769 - accuracy: 0.0000e+00
# Epoch 11/50
# 1/1 - 0s - loss: 0.3661 - accuracy: 0.0000e+00
# Epoch 12/50
# 1/1 - 0s - loss: 0.3553 - accuracy: 0.0000e+00
# Epoch 13/50
# 1/1 - 0s - loss: 0.3445 - accuracy: 0.0000e+00
# Epoch 14/50
# 1/1 - 0s - loss: 0.3335 - accuracy: 0.0000e+00
# Epoch 15/50
# 1/1 - 0s - loss: 0.3223 - accuracy: 0.0000e+00
# Epoch 16/50
# 1/1 - 0s - loss: 0.3111 - accuracy: 0.0000e+00
# Epoch 17/50
# 1/1 - 0s - loss: 0.3021 - accuracy: 0.0000e+00
# Epoch 18/50
# 1/1 - 0s - loss: 0.2940 - accuracy: 0.0000e+00
# Epoch 19/50
# 1/1 - 0s - loss: 0.2859 - accuracy: 0.0000e+00
# Epoch 20/50
# 1/1 - 0s - loss: 0.2777 - accuracy: 0.0000e+00
# Epoch 21/50
# 1/1 - 0s - loss: 0.2694 - accuracy: 0.0000e+00
# Epoch 22/50
# 1/1 - 0s - loss: 0.2610 - accuracy: 0.0000e+00
# Epoch 23/50
# 1/1 - 0s - loss: 0.2525 - accuracy: 0.0667
# Epoch 24/50
# 1/1 - 0s - loss: 0.2439 - accuracy: 0.0667
# Epoch 25/50
# 1/1 - 0s - loss: 0.2368 - accuracy: 0.0667
# Epoch 26/50
# 1/1 - 0s - loss: 0.2330 - accuracy: 0.0667
# Epoch 27/50
# 1/1 - 0s - loss: 0.2327 - accuracy: 0.0667
# Epoch 28/50
# 1/1 - 0s - loss: 0.2339 - accuracy: 0.0667
# Epoch 29/50
# 1/1 - 0s - loss: 0.2345 - accuracy: 0.0667
# Epoch 30/50
# 1/1 - 0s - loss: 0.2342 - accuracy: 0.0667
# Epoch 31/50
# 1/1 - 0s - loss: 0.2333 - accuracy: 0.0667
# Epoch 32/50
# 1/1 - 0s - loss: 0.2320 - accuracy: 0.0667
# Epoch 33/50
# 1/1 - 0s - loss: 0.2296 - accuracy: 0.0667
# Epoch 34/50
# 1/1 - 0s - loss: 0.2262 - accuracy: 0.0667
# Epoch 35/50
# 1/1 - 0s - loss: 0.2221 - accuracy: 0.0667
# Epoch 36/50
# 1/1 - 0s - loss: 0.2182 - accuracy: 0.0667
# Epoch 37/50
# 1/1 - 0s - loss: 0.2140 - accuracy: 0.0667
# Epoch 38/50
# 1/1 - 0s - loss: 0.2096 - accuracy: 0.0667
# Epoch 39/50
# 1/1 - 0s - loss: 0.2051 - accuracy: 0.0667
# Epoch 40/50
# 1/1 - 0s - loss: 0.2009 - accuracy: 0.0667
# Epoch 41/50
# 1/1 - 0s - loss: 0.1977 - accuracy: 0.0667
# Epoch 42/50
# 1/1 - 0s - loss: 0.1945 - accuracy: 0.0667
# Epoch 43/50
# 1/1 - 0s - loss: 0.1918 - accuracy: 0.0667
# Epoch 44/50
# 1/1 - 0s - loss: 0.1916 - accuracy: 0.0667
# Epoch 45/50
# 1/1 - 0s - loss: 0.1903 - accuracy: 0.0667
# Epoch 46/50
# 1/1 - 0s - loss: 0.1879 - accuracy: 0.0667
# Epoch 47/50
# 1/1 - 0s - loss: 0.1846 - accuracy: 0.0667
# Epoch 48/50
# 1/1 - 0s - loss: 0.1804 - accuracy: 0.0667
# Epoch 49/50
# 1/1 - 0s - loss: 0.1764 - accuracy: 0.0667
# Epoch 50/50
# 1/1 - 0s - loss: 0.1735 - accuracy: 0.0667

# %%
model = Sequential()
model.add(layers.LSTM(128,  input_shape=(train_X.shape[1], train_X.shape[2]), activation='tanh', recurrent_activation='elu', return_sequences = False, stateful = False, name='lstm_layer'))
model.add(layers.Dropout(0.5, name = 'dropout_layer'))
model.add(layers.Dense(units=1, activation = 'softmax', name='dense_layer'))
optimizer = tf.keras.optimizers.RMSprop(lr=0.001)
model.compile(loss = 'categorical_crossentropy', optimizer = optimizer, metrics=['accuracy'])
history = model.fit(train_X, train_y, validation_data=(test_X, test_y), epochs = 50, batch_size = 70, shuffle = True)

# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0000e+00 - accuracy: 0.0667 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
from keras.layers import concatenate
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)

# %%
inv_yhat
# Out:
# <tf.Tensor: shape=(5, 59), dtype=float32, numpy=
# array([[1.00000000e+00, 0.00000000e+00, 5.05451899e-05, 0.00000000e+00,
#         3.37320566e-01, 2.69893169e-01, 8.70373011e-01, 7.08832264e-01,
#         3.58651400e-01, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.02833314e-04, 0.00000000e+00, 8.80382717e-01, 1.00000000e+00,
#         4.49962854e-01, 4.61763769e-01, 6.67253137e-01, 4.75021362e-01,
#         0.00000000e+00, 0.00000000e+00, 1.10618144e-01, 0.00000000e+00,
#         5.78947365e-01, 6.57140493e-01, 6.17443562e-01, 9.78427172e-01,
#         4.15050805e-01, 5.77346802e-01, 0.00000000e+00, 0.00000000e+00,
#         7.41862178e-01, 0.00000000e+00, 7.94258356e-01, 9.53787804e-01,
#         1.23814344e-01, 2.24474370e-02, 5.45519590e-01, 6.81762695e-02,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#         9.99999940e-01, 4.55558300e-01, 3.77049208e-01, 5.50443381e-02,
#         3.06935191e-01, 4.46166992e-02, 0.00000000e+00, 0.00000000e+00,
#         9.26095903e-01, 0.00000000e+00, 3.82775106e-02, 3.43623161e-01,
#         1.00000000e+00, 9.38217282e-01, 4.11058843e-01],
#        [1.00000000e+00, 0.00000000e+00, 1.02833314e-04, 0.00000000e+00,
#         8.80382717e-01, 1.00000000e+00, 4.49962854e-01, 4.61763769e-01,
#         6.67253137e-01, 4.75021362e-01, 0.00000000e+00, 0.00000000e+00,
#         1.10618144e-01, 0.00000000e+00, 5.78947365e-01, 6.57140493e-01,
#         6.17443562e-01, 9.78427172e-01, 4.15050805e-01, 5.77346802e-01,
#         0.00000000e+00, 0.00000000e+00, 7.41862178e-01, 0.00000000e+00,
#         7.94258356e-01, 9.53787804e-01, 1.23814344e-01, 2.24474370e-02,
#         5.45519590e-01, 6.81762695e-02, 0.00000000e+00, 0.00000000e+00,
#         1.00000000e+00, 0.00000000e+00, 9.99999940e-01, 4.55558300e-01,
#         3.77049208e-01, 5.50443381e-02, 3.06935191e-01, 4.46166992e-02,
#         0.00000000e+00, 0.00000000e+00, 9.26095903e-01, 0.00000000e+00,
#         3.82775106e-02, 3.43623161e-01, 1.00000000e+00, 9.38217282e-01,
#         4.11058843e-01, 1.71966553e-02, 5.10928929e-01, 0.00000000e+00,
#         8.76259208e-01, 0.00000000e+00, 2.39234436e-02, 5.46775818e-01,
#         8.46294880e-01, 6.65252805e-01, 4.96038795e-01],
#        [1.00000000e+00, 0.00000000e+00, 1.10618144e-01, 0.00000000e+00,
#         5.78947365e-01, 6.57140493e-01, 6.17443562e-01, 9.78427172e-01,
#         4.15050805e-01, 5.77346802e-01, 0.00000000e+00, 0.00000000e+00,
#         7.41862178e-01, 0.00000000e+00, 7.94258356e-01, 9.53787804e-01,
#         1.23814344e-01, 2.24474370e-02, 5.45519590e-01, 6.81762695e-02,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#         9.99999940e-01, 4.55558300e-01, 3.77049208e-01, 5.50443381e-02,
#         3.06935191e-01, 4.46166992e-02, 0.00000000e+00, 0.00000000e+00,
#         9.26095903e-01, 0.00000000e+00, 3.82775106e-02, 3.43623161e-01,
#         1.00000000e+00, 9.38217282e-01, 4.11058843e-01, 1.71966553e-02,
#         5.10928929e-01, 0.00000000e+00, 8.76259208e-01, 0.00000000e+00,
#         2.39234436e-02, 5.46775818e-01, 8.46294880e-01, 6.65252805e-01,
#         4.96038795e-01, 7.36404419e-01, 1.00000000e+00, 1.00000000e+00,
#         8.64602447e-01, 0.00000000e+00, 2.39234436e-02, 0.00000000e+00,
#         1.10084057e-01, 1.17218375e-01, 6.82758808e-01],
#        [1.00000000e+00, 0.00000000e+00, 7.41862178e-01, 0.00000000e+00,
#         7.94258356e-01, 9.53787804e-01, 1.23814344e-01, 2.24474370e-02,
#         5.45519590e-01, 6.81762695e-02, 0.00000000e+00, 0.00000000e+00,
#         1.00000000e+00, 0.00000000e+00, 9.99999940e-01, 4.55558300e-01,
#         3.77049208e-01, 5.50443381e-02, 3.06935191e-01, 4.46166992e-02,
#         0.00000000e+00, 0.00000000e+00, 9.26095903e-01, 0.00000000e+00,
#         3.82775106e-02, 3.43623161e-01, 1.00000000e+00, 9.38217282e-01,
#         4.11058843e-01, 1.71966553e-02, 5.10928929e-01, 0.00000000e+00,
#         8.76259208e-01, 0.00000000e+00, 2.39234436e-02, 5.46775818e-01,
#         8.46294880e-01, 6.65252805e-01, 4.96038795e-01, 7.36404419e-01,
#         1.00000000e+00, 1.00000000e+00, 8.64602447e-01, 0.00000000e+00,
#         2.39234436e-02, 0.00000000e+00, 1.10084057e-01, 1.17218375e-01,
#         6.82758808e-01, 0.00000000e+00, 4.64480855e-02, 5.54880977e-01,
#         8.22818995e-01, 0.00000000e+00, 1.19617218e-02, 3.56534481e-01,
#         7.08559513e-01, 3.59246612e-01, 3.89684081e-01],
#        [1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#         9.99999940e-01, 4.55558300e-01, 3.77049208e-01, 5.50443381e-02,
#         3.06935191e-01, 4.46166992e-02, 0.00000000e+00, 0.00000000e+00,
#         9.26095903e-01, 0.00000000e+00, 3.82775106e-02, 3.43623161e-01,
#         1.00000000e+00, 9.38217282e-01, 4.11058843e-01, 1.71966553e-02,
#         5.10928929e-01, 0.00000000e+00, 8.76259208e-01, 0.00000000e+00,
#         2.39234436e-02, 5.46775818e-01, 8.46294880e-01, 6.65252805e-01,
#         4.96038795e-01, 7.36404419e-01, 1.00000000e+00, 1.00000000e+00,
#         8.64602447e-01, 0.00000000e+00, 2.39234436e-02, 0.00000000e+00,
#         1.10084057e-01, 1.17218375e-01, 6.82758808e-01, 0.00000000e+00,
#         4.64480855e-02, 5.54880977e-01, 8.22818995e-01, 0.00000000e+00,
#         1.19617218e-02, 3.56534481e-01, 7.08559513e-01, 3.59246612e-01,
#         3.89684081e-01, 1.51962280e-01, 5.73770478e-02, 2.81140447e-01,
#         7.93542027e-01, 0.00000000e+00, 0.00000000e+00, 8.25552464e-01,
#         7.96490908e-01, 1.55481994e-02, 6.14426374e-01]], dtype=float32)>

# %%
import math
from sklearn.metrics import mean_squared_error


#inv_yhat = scaler.inverse_transform(inv_yhat)

inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
#inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.749
